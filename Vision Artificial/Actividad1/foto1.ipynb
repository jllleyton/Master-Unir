# %%
#foreground
#Denoising → Gamma (0.6–0.8) → CLAHE → Estiramiento no lineal
import sys
from helpers import funciones
from helpers import mostrar

img = funciones.read("./imagenes/Imagen4_original.png")
gamma = 0.5
img_gamma =funciones.gamma(img,gamma)

img_2=funciones.highlight_compression(img_gamma)

a = 15
b = 0.25
#final = funciones.sigmoid_transform(img_2,a,b)
final = funciones.clahe(img_2)
funciones.write("foto1_procesada.png", img_2)
mostrar.mostrar(img,final)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 #foreground
#       2 #Denoising → Gamma (0.6–0.8) → CLAHE → Estiramiento no lineal
#       3 import sys
# ----> 4 from helpers import funciones
#       5 from helpers import mostrar
#       7 img = funciones.read("./imagenes/Imagen4_original.png")
#
# File c:\workspace\Master-Unir\Vision Artificial\Actividad1\helpers\funciones.py:2
#       1 import numpy as np
# ----> 2 import cv2
#       4 def read(file):
#       5     imagen = cv2.imread(file)
#
# ModuleNotFoundError: No module named 'cv2'
